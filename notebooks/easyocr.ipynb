# %%
import easyocr

# %%
reader = easyocr.Reader(['ch_sim','en']) # this needs to run only once to load the model into memory
# Out:
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
result = reader.readtext(r'D:\code\python\piephi\samples\images\sample3.png')

# %%
reader.detect()
# Out:
# [([[457, 13], [499, 13], [499, 27], [457, 27]], 'Dute', 0.23823992908000946),
#  ([[525, 15], [611, 15], [611, 31], [525, 31]],
#   'SeLLCIW',
#   0.044743470327905446),
#  ([[617, 15], [641, 15], [641, 29], [617, 29]], '21', 0.5905556578877228),
#  ([[273, 47], [331, 47], [331, 63], [273, 63]], 'Samplc', 0.47804795047459203),
#  ([[337, 47], [361, 47], [361, 61], [337, 61]], '00', 0.18075211901749733),
#  ([[387, 47], [427, 47], [427, 63], [387, 63]], '5030', 0.9271027445793152),
#  ([[201, 79], [241, 79], [241, 97], [201, 97]], 'Tybe', 0.6803759336471558),
#  ([[245, 79], [267, 79], [267, 93], [245, 93]], '0f', 0.6391442942768082),
#  ([[273, 77], [359, 77], [359, 95], [273, 95]],
#   'Cigarette',
#   0.7908422584194292),
#  ([[415, 79], [437, 79], [437, 91], [415, 91]], 'I', 0.8512608773053252),
#  ([[442, 74], [501, 74], [501, 95], [442, 95]], 'Liter', 0.10586005885100361),
#  ([[265, 109], [313, 109], [313, 125], [265, 125]],
#   'BatCh',
#   0.7498312204770398),
# ...
